# %% [markdown]
# # Playing with a notebook on github

# %%
import pandas as pd, numpy as np, ipyvolume as ipv
# %matplotlib inline
# Out:
# /home/ubuntu/anaconda3/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ubuntu/anaconda3/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
a = pd.DataFrame(np.random.randn(1000,1000)).cumsum().plot(style='b-', alpha=0.01, legend=False)

# %%
th = np.arange(0, 4*2*np.pi, 0.01)
x  = th * np.cos(th)
y  = th * np.sin(th)

# %%
ipv.quickscatter(th,x,y)
